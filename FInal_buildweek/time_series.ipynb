# %%
import pandas as pd
import numpy as np
import random
import pickle
from time import time, sleep

# %%
df = pd.read_csv("./times_series_test.csv")

# %%
df.head()
# Out:
#    android_sensor_gyroscope_mean  android_sensor_accelerometer_std  \
# 0                       0.001651                          0.014626
# 1                       0.001525                          0.011199
# 2                       0.001669                          0.013051
# 3                       0.001690                          0.023715
# 4                       0.001625                          0.016184
#
#    android_sensor_gyroscope_std  android_sensor_gyroscope_uncalibrated_mean  \
# 0                      0.000737                                    0.016221
# 1                      0.000713                                    0.016302
# 2                      0.000686                                    0.015879
# 3                      0.000791                                    0.016217
# 4                      0.000731                                    0.016417
#
#    android_sensor_accelerometer_max  android_sensor_linear_acceleration_mean  \
# 0                          9.849411                                 0.020978
# 1                          9.849262                                 0.034110
# 2                          9.867058                                 0.016455
# 3                          9.880349                                 0.031281
# 4                          9.852852                                 0.021487
#
#    android_sensor_rotation_vector_mean  android_sensor_rotation_vector_max  \
# 0                             0.050413                            0.056351
# 1                             0.610456                            0.610456
# 2                             0.965332                            0.965332
# 3                             0.885837                            0.885837
# 4                             0.048799                            0.054386
#
#    android_sensor_accelerometer_min  \
# 0                          9.758895
# 1                          9.804817
# 2                          9.814482
# 3                          9.765504
# 4                          9.780049
#
#    android_sensor_magnetic_field_uncalibrated_min  sound_min target  user
# 0                                       51.199707  83.859708  Still  Luca
# 1                                       55.501802  83.859708  Still  Luca
# 2                                       21.466718  83.859708  Still  Luca
# 3                                       45.736420  83.859708  Still  Luca
# 4                                       51.270752  83.859708  Still  Luca

# %%
X_test = df.drop(['target', 'user'], axis = 1)

# %%
Y_test = df.target.replace({'Still':0, 'Walking':1})

# %%
#load the model from disk
loaded_model = pickle.load(open('finalized_model.sav', 'rb'))
result = loaded_model.score(X_test, Y_test)
print(result)
# Out:
# 0.0

# %%
predictions = []

for row in range(df.shape[0]):
    sleep(1)
    pred = random.randrange(0,3)
    #pred = model.predict(X_test)
    if pred == 0:
        pred.append(0)
    elif pred == 1:
        pred.append(1)
    elif pred == 2:
        pred.append(2)
    elif pred == 3:
        pred.append(3)
        
    if predictions == 5:
        
        still_cont  = 0
        walk_cont  = 0
        car_cont  = 0
        bus_cont  = 0
        
        for p in predictions:
            if p == 0:
                still_cont += 1
            elif p == 1:
                walk_cont += 1
            elif p == 2:
                car_cont += 1
            elif p == 3:
                bus_cont += 1
        
        if still_cont >= 2:
            print('You are currently in still position')
        elif walk_cont >= 2:
            print('You are currently walking')
        elif car_cont >= 2:
            print('You are currently in a car')
        elif bus_cont >= 2:
            print('You are currently in a bu')
        
        predictions.remove(predictions[0])

# %%
import pandas as pd
import numpy as np
from time import time, sleep
import joblib
from sklearn.preprocessing import MinMaxScaler, Normalizer, PowerTransformer, QuantileTransformer, RobustScaler, StandardScaler, LabelEncoder, OneHotEncoder, OrdinalEncoder
from sklearn.decomposition import PCA
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn import set_config, impute, compose
from sklearn.metrics import accuracy_score, balanced_accuracy_score, plot_confusion_matrix, roc_auc_score

df = pd.read_csv('sample.csv')
X = df.drop('target', axis=1)
y = df.target
preprocessor = joblib.load('preprocessor.x')
model = joblib.load('model.x')
clf = Pipeline([('pre', preprocessor), ('classification', model)])
clf.predict(X)
score = clf.score(X, y)*100
print("model score: %.1f" % score)

predictions = []
for i in range(df.shape[0]):
    x_test = df.drop('target', axis=1).values[i].reshape(1, -1)
    x_test = pd.DataFrame(x_test, columns=df.drop('target', axis=1).columns)
    sleep(1)
    pred = clf.predict(x_test)
    if pred == 'Car':
        predictions.append('Car')
    elif pred == 'Still':
        predictions.append('Still')
    elif pred == 'Walking':
        predictions.append('Walking')

    if len(predictions) == 5:
        still_cont = 0
        walk_cont = 0
        car_cont = 0
        sleep(1)
        for p in predictions:
            if p == 'Still':
                still_cont += 1
            elif p == 'Car':
                car_cont += 1
            elif p == 'Walking':
                walk_cont += 1
        if still_cont >= 3:
            print('You are currently in still position')
        elif walk_cont >= 3:
            print('You are currently walking')
        elif car_cont >= 3:
            print('You are currently in a car')
        predictions.remove(predictions[0])
# Out:
# C:\Users\User\anaconda3\envs\ML\lib\site-packages\sklearn\base.py:310: UserWarning: Trying to unpickle estimator SimpleImputer from version 0.24.2 when using version 0.24.1. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# C:\Users\User\anaconda3\envs\ML\lib\site-packages\sklearn\base.py:310: UserWarning: Trying to unpickle estimator MinMaxScaler from version 0.24.2 when using version 0.24.1. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# C:\Users\User\anaconda3\envs\ML\lib\site-packages\sklearn\base.py:310: UserWarning: Trying to unpickle estimator Pipeline from version 0.24.2 when using version 0.24.1. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# C:\Users\User\anaconda3\envs\ML\lib\site-packages\sklearn\base.py:310: UserWarning: Trying to unpickle estimator ColumnTransformer from version 0.24.2 when using version 0.24.1. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# C:\Users\User\anaconda3\envs\ML\lib\site-packages\sklearn\base.py:310: UserWarning: Trying to unpickle estimator LabelEncoder from version 0.24.2 when using version 0.24.1. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# model score: 93.3
# You are currently in still position
# You are currently in still position
# You are currently in still position
# You are currently in still position
# You are currently in still position
# You are currently in still position
# You are currently in still position
# You are currently in still position
# You are currently in a car
# You are currently in a car
# You are currently in a car
# You are currently in a car
# You are currently in a car
# You are currently in a car
# You are currently in a car
# You are currently in a car
# You are currently in a car
# You are currently in a car
# You are currently walking
# You are currently walking
# You are currently walking
# You are currently walking
# You are currently walking
# You are currently walking
# You are currently walking
# You are currently walking

# %%
df1 = df.android_sensor_accelerometer_mean
df.head()
# Out:
#    activityrecognition_1  android_sensor_accelerometer_mean  \
# 0                  100.0                           9.450422
# 1                   15.0                           9.476637
# 2                   77.0                           9.674269
# 3                   15.0                           9.489538
# 4                   77.0                           9.396438
#
#    android_sensor_accelerometer_min  android_sensor_accelerometer_max  \
# 0                          9.429991                          9.469626
# 1                          9.462833                          9.498124
# 2                          9.134530                         10.113713
# 3                          9.403752                          9.532847
# 4                          9.356411                          9.437865
#
#    android_sensor_accelerometer_std  android_sensor_game_rotation_vector_mean  \
# 0                          0.016203                                  0.813843
# 1                          0.014979                                  0.642445
# 2                          0.350043                                  0.681375
# 3                          0.041134                                  0.644381
# 4                          0.033397                                  0.618250
#
#    android_sensor_game_rotation_vector_min  \
# 0                                 0.813843
# 1                                 0.642445
# 2                                 0.615823
# 3                                 0.643973
# 4                                 0.618211
#
#    android_sensor_game_rotation_vector_max  \
# 0                                 0.813843
# 1                                 0.642445
# 2                                 0.774514
# 3                                 0.644789
# 4                                 0.618290
#
#    android_sensor_game_rotation_vector_std  android_sensor_gravity_mean  ...  \
# 0                                 0.000801                     9.806650  ...
# 1                                 0.000292                     9.806650  ...
# 2                                 0.082864                     9.806651  ...
# 3                                 0.000577                     9.806650  ...
# 4                                 0.000056                     9.806650  ...
#
#    android_sensor_step_counter_min  android_sensor_step_counter_max  \
# 0                              NaN                              NaN
# 1                              NaN                              NaN
# 2                              NaN                              NaN
# 3                              NaN                              NaN
# 4                              NaN                              NaN
#
#    sound_mean  sound_min  sound_max  sound_std  speed_mean  speed_min  \
# 0   49.938593  49.938593  49.938593  12.131488         NaN        NaN
# 1   60.555144  60.555144  60.555144        NaN         NaN        NaN
# 2   49.855208  49.855208  49.855208        NaN         0.0        0.0
# 3   56.028074  56.028074  56.028074        NaN         NaN        NaN
# 4         NaN        NaN        NaN        NaN         0.0        0.0
#
#    speed_max  target
# 0        NaN   Still
# 1        NaN   Still
# 2        0.0   Still
# 3        NaN   Still
# 4        0.0   Still
#
# [5 rows x 59 columns]
